# %%
# !pip install --quiet -U  pyserini jsonlines

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = './data'
# !mkdir data && cp /content/drive/MyDrive/DATASETS/MachineLearning/topicmodeling/lenta-ru-filtered.csv data

# %% [markdown]
# ## Библиотеки

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from matplotlib import gridspec

from tqdm.notebook import tqdm
import numpy as np
import  pandas as pd
import seaborn as sns
import torch
import scipy
import json
import re
import os
import jsonlines

from pyserini.search import SimpleSearcher

# %% [markdown]
# ## Загружаем данные

# %%
data = pd.read_csv('data/lenta-ru-filtered.csv')

# %%
data
# Out:
#                                                      text  ...        date
# 0       С 1 сентября на всей территории России вводитс...  ...  31-08-1999
# 1       По сведениям миссии ООН, передаваемым РИА "Нов...  ...  31-08-1999
# 2       15 представителей национал-большевистской парт...  ...  31-08-1999
# 3       Намеченная на сегодняшний день церемония вступ...  ...  31-08-1999
# 4       На юге Киргизии, а именно в Баткенском и Чон-А...  ...  31-08-1999
# ...                                                   ...  ...         ...
# 863280  Популярное место среди туристов в Мурманской о...  ...  11-09-2020
# 863281  Рейтинги от международного рейтингового агентс...  ...  11-09-2020
# 863282  Российские ученые нашли в Якутии новый подвид ...  ...  11-09-2020
# 863283  Для указания коронавируса как причины смерти ч...  ...  11-09-2020
# 863284  Президент США Дональд Трамп стал посредником в...  ...  11-09-2020
#
# [863285 rows x 4 columns]

# %% [markdown]
# ## Описания поисковика

# %% [markdown]
# ## Генерация документов

# %%
COLLECTION_DIR = 'data/collection/lenta'
if not os.path.exists(COLLECTION_DIR):
    os.makedirs(COLLECTION_DIR)

collection = data.values

bath_size = 32768
for ind in tqdm(range(0, len(collection), bath_size)):
    files = [{'id': ind+i, 
              'contents': doc[0],
              'tag': doc[1],
              'date': doc[-1]}
             for i, doc in enumerate(collection[ind:ind+bath_size])]
    with jsonlines.open(os.path.join(COLLECTION_DIR, 
                                     '{}.jsonl'.format(ind)), 
                        mode='w') as writer:
        writer.write_all(files)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]

# %%
with open(os.path.join(COLLECTION_DIR, 
                       '{}.jsonl'.format(ind))) as f:
  print('\n'.join(f.read().splitlines()[-5:]))
# Out:
# {"id": 863280, "contents": "Популярное место среди туристов в Мурманской области завалили мусором и навозом. Об этом сообщает местное издание «Мурманский вестник». По данным портала, речь идет о Лавнинских водопадах в Кольском районе региона, ставших одним из излюбленных мест отдыха северян, где можно «искупаться и сделать красивые фотографии». Местные жители жалуются, что туристы не убирают за собой мусор и пластиковые бутылки, а недавно там появились огромные лужи навоза. «На всем пути к Лавне \"аромат\" такой, аж оторопь берет... Особое негодование вызывают болотного вида лужи навоза, смердящего и отравляющего воду. А ведь лет пять назад мы набирали чайник прямо из водопада, не боялись отравиться нечистотами», — рассказала жительница района Лиза Титова. Откуда взялся навоз возле водопадов, неизвестно, но люди предполагают, что во всем могут быть виноваты фермеры, сливающие отходы на территорию курорта. В июне сообщалось, что жители английского города Бакстон подговорили фермеров забросать навозом знаменитую голубую лагуну, чтобы отпугнуть от нее толпы приезжих. Местный репортер, побывавший возле лагуны, отметил, что место действительно потеряло былую привлекательность, поскольку уже на подъезде к нему «в нос ударяет отвратительный запах».", "tag": "Россия", "date": "11-09-2020"}
# {"id": 863281, "contents": "Рейтинги от международного рейтингового агентства S&P крупнейших банков Белоруссии — Беларусбанка, Белагропромбанка и Банка БелВЭБ — помещены в список на пересмотр с негативными ожиданиями из-за ряда проблем. Об этом говорится в сообщении организации, которое есть в распоряжении «Ленты.ру». Главной причиной стали ускорившийся отток вкладов и повышенный спрос на валюту, которые, в свою очередь, связаны с ситуацией после президентских выборов. Негативный эффект могут оказать государственные ограничения на хождение иностранной валюты или движение капитала, если их введут, а также отсутствие адекватной поддержки от Нацбанка. Эксперты не исключают быстрого сокращения запасов ликвидности банков. В конце текущего и начале следующего года слабые экономические показатели белорусской экономики могут снизить и прибыльность, и капитализацию указанных банков. Если это произойдет, то все три банка в течение трех месяцев лишатся рейтинга «В». В S&P отмечают, что ситуация в экономике и политическая неопределенность уже привели к обесцениванию курса национальной валюты на 20 процентов по отношению к доллару. В дальнейшем банки могут столкнуться с массовыми неплатежами по кредитам. Запасы капитала белорусских банков оцениваются как низкие по международным стандартам. Ранее о возможности снижения собственных рейтингов Беларусбанка, Белинвестбанка, Белгазпромбанка и БПС-Сбербанка заявили в аналитическом агентстве Moody's,", "tag": NaN, "date": "11-09-2020"}
# {"id": 863282, "contents": "Российские ученые нашли в Якутии новый подвид арктических бабочек. Об этом ТАСС сообщил профессор кафедры экологии, биохимии и биотехнологии АлтГУ Роман Яковлев. Находка была обнаружена во время экспедиции сотрудников Алтайского государственного университета (АлтГУ) и Зоологического института РАН (Санкт-Петербург). Новую бабочку поймали за полярным кругом, высоко в горах на высоте 1,4 тысячи метров над уровнем моря. «Это огромная высота для тех широт — там фактически нет растительности, одни камни», — уточнил Яковлев. По его словам, обнаружение бабочки можно считать сенсацией, поскольку эта группа насекомых считается хорошо изученной. Он отметил, что открытие стало возможным из-за того, что до сих пор в России есть малоизученные участки, в первую очередь на севере. Новые бабочки внешне похожи на представителей самого редкого вида заполярных бабочек из семейства парусников, но они крупнее, с более продолговатыми крыльями без рисунка и с красными штрихами. В ходе морфологических и генетических анализов были выявлены отличия нового подвида от известных видов Parnassius tenedius и Parnassius arcticus. Новому насекомому дали название Parnassius arcticus arbugaevi в честь директора эколого-этнографического комплекса «Чочур Муран» Германа Арбугаева, который помогал биологам в изучении.", "tag": "События", "date": "11-09-2020"}
# {"id": 863283, "contents": "Для указания коронавируса как причины смерти человека необходимо патологоанатомическое заключение, оно обязательно в случае летального исхода при инфекционном заболевании. Это и другие правила учета смертей от COVID-19 в России перечислены на сайте «Стопкоронавирус.рф». В России в списки умерших попадают только те, у кого главной причиной смерти стал коронавирус, а не уже имеющиеся хронические заболевания, обострившиеся из-за инфекции. Речь идет о разнице формулировок — «смерть от COVID-19», когда коронавирус стал прямой причиной смерти, и «смерть с COVID-19», когда есть подтверждение заражения, но к летальному исходу привели другие причины. В публикации так же сказано, что по итогам вскрытия диагноз «коронавирусная инфекция» может быть поставлен и в том случае, если тест был отрицательным. Как объяснил главный внештатный патологоанатом Минздрава, профессор и академик РАН Георгий Франк, если у человека есть, например, рак желудка с метастазами, и легкая форма коронавируса, то на первое место выходит рак — он приводит к гибели пациента. Может быть и наоборот, когда онкологическое заболевание слабее инфекции, и уходит на второй план. В публикации сказано, что «число умерших — это всегда отсроченное число», потому что коронавирус длится долго и пациент может провести в больнице несколько недель, а исход болезни непредсказуем наверняка. В связи с этим нет смысла считать смертность в момент пика и сравнивать со странами, которые уже прошли пик. На «Стопкоронавирус.рф» уточнили, что ежедневно публикуют только те случаи смерти, в которых коронавирус стал основной причиной. 7 сентября глава Росздравнадзора Алла Самойлова заявила, что в России обнаружили больницы, скрывавшие смертность пациентов от коронавируса. Она объяснила, что в некоторых больницах «практически ноль» летальных случаев преподносились как смертность от COVID-19 — ее переносили на другие заболевания. Глава Минздрава Михаил Мурашко на это ответил, что выводы ведомства не учитывают данные по всей России, так как они были сделаны на основе проверок отдельных учреждений.", "tag": "Общество", "date": "11-09-2020"}
# {"id": 863284, "contents": "Президент США Дональд Трамп стал посредником в новом примирении на Ближнем Востоке: Бахрейн установил дипломатические отношения с Израилем. Об этом американский лидер объявил у себя в Twitter. «Сегодня —  еще один исторический прорыв! Двое наших замечательных друзей, Израиль и Королевство Бахрейн, договорились заключить мир — вторая арабская страна, заключившая мир с Израилем за 30 дней», — написал Трамп. В совместном заявлении страны объявили, что этот шаг позволит дальше двигаться к миру во всем регионе. Как отмечают эксперты Reuters, этот процесс связан с усилением Ирана, которое видится угрозой большинству его соседей по Ближнему Востоку. Ранее 11 сентября стало известно, что Трампа во второй раз за последнее время выдвинули на Нобелевскую премию мира. Один из авторов этой инициативы считает, что американский президент заслуживает ее за примирение Израиля и Объединенных Арабских Эмиратов, другой — что его стоит наградить за нормализацию отношений между Сербией и частично признанной республикой Косово.", "tag": "Политика", "date": "11-09-2020"}

# %% [markdown]
# ## Построение индекса

# %%
INDEX_DIR = 'data/index/lenta'
if not os.path.exists(INDEX_DIR):
    os.makedirs(INDEX_DIR)

# %%
# !python -m pyserini.index -collection JsonCollection -generator DefaultLuceneDocumentGenerator \
 -threads 16 -input {COLLECTION_DIR} \
 -index {INDEX_DIR} -storePositions -storeDocvectors -storeRaw
# Out:
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# 2021-03-18 21:09:16,821 INFO  [main] index.IndexCollection (IndexCollection.java:655) - Setting log level to INFO
# 2021-03-18 21:09:16,825 INFO  [main] index.IndexCollection (IndexCollection.java:658) - Starting indexer...
# 2021-03-18 21:09:16,825 INFO  [main] index.IndexCollection (IndexCollection.java:659) - ============ Loading Parameters ============
# 2021-03-18 21:09:16,826 INFO  [main] index.IndexCollection (IndexCollection.java:660) - DocumentCollection path: data/collection/lenta
# 2021-03-18 21:09:16,827 INFO  [main] index.IndexCollection (IndexCollection.java:661) - CollectionClass: JsonCollection
# 2021-03-18 21:09:16,828 INFO  [main] index.IndexCollection (IndexCollection.java:662) - Generator: DefaultLuceneDocumentGenerator
# 2021-03-18 21:09:16,828 INFO  [main] index.IndexCollection (IndexCollection.java:663) - Threads: 16
# 2021-03-18 21:09:16,829 INFO  [main] index.IndexCollection (IndexCollection.java:664) - Stemmer: porter
# 2021-03-18 21:09:16,829 INFO  [main] index.IndexCollection (IndexCollection.java:665) - Keep stopwords? false
# 2021-03-18 21:09:16,829 INFO  [main] index.IndexCollection (IndexCollection.java:666) - Stopwords:  null
# 2021-03-18 21:09:16,830 INFO  [main] index.IndexCollection (IndexCollection.java:667) - Store positions? true
# 2021-03-18 21:09:16,830 INFO  [main] index.IndexCollection (IndexCollection.java:668) - Store docvectors? true
# 2021-03-18 21:09:16,831 INFO  [main] index.IndexCollection (IndexCollection.java:669) - Store document "contents" field? false
# 2021-03-18 21:09:16,831 INFO  [main] index.IndexCollection (IndexCollection.java:670) - Store document "raw" field? true
# 2021-03-18 21:09:16,832 INFO  [main] index.IndexCollection (IndexCollection.java:671) - Optimize (merge segments)? false
# 2021-03-18 21:09:16,832 INFO  [main] index.IndexCollection (IndexCollection.java:672) - Whitelist: null
# 2021-03-18 21:09:16,833 INFO  [main] index.IndexCollection (IndexCollection.java:692) - Directly building Lucene indexes...
# 2021-03-18 21:09:16,833 INFO  [main] index.IndexCollection (IndexCollection.java:693) - Index path: data/index/lenta
# 2021-03-18 21:09:16,836 INFO  [main] index.IndexCollection (IndexCollection.java:742) - ============ Indexing Collection ============
# 2021-03-18 21:09:17,028 INFO  [main] index.IndexCollection (IndexCollection.java:799) - Thread pool with 16 threads initialized.
# 2021-03-18 21:09:17,029 INFO  [main] index.IndexCollection (IndexCollection.java:801) - Initializing collection in data/collection/lenta
# 2021-03-18 21:09:17,034 INFO  [main] index.IndexCollection (IndexCollection.java:804) - 27 files found
# 2021-03-18 21:09:17,034 INFO  [main] index.IndexCollection (IndexCollection.java:805) - Starting to index...
# 2021-03-18 21:09:17,358 ERROR [pool-2-thread-9] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-9: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 2, column: 1418]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 2, column: 1418]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:17,551 ERROR [pool-2-thread-10] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-10: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 3, column: 1004]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 3, column: 1004]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:17,619 ERROR [pool-2-thread-13] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-13: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 4, column: 1886]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 4, column: 1886]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:18,162 ERROR [pool-2-thread-5] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-5: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 19, column: 2122]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 19, column: 2122]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:19,032 ERROR [pool-2-thread-7] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-7: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 63, column: 950]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 63, column: 950]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:19,066 ERROR [pool-2-thread-7] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-7: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 3, column: 1983]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 3, column: 1983]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:19,209 ERROR [pool-2-thread-15] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-15: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 63, column: 2933]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 63, column: 2933]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:19,233 ERROR [pool-2-thread-5] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-5: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 54, column: 598]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 54, column: 598]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:19,377 ERROR [pool-2-thread-4] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-4: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 83, column: 923]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 83, column: 923]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:19,401 ERROR [pool-2-thread-5] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-5: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 13, column: 1680]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 13, column: 1680]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:20,396 ERROR [pool-2-thread-8] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-8: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 156, column: 1113]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 156, column: 1113]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:20,749 ERROR [pool-2-thread-8] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-8: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 27, column: 1745]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 27, column: 1745]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:20,762 ERROR [pool-2-thread-15] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-15: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 118, column: 1191]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 118, column: 1191]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:20,803 ERROR [pool-2-thread-6] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-6: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 181, column: 1050]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 181, column: 1050]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:20,987 ERROR [pool-2-thread-16] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-16: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 215, column: 812]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 215, column: 812]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:22,936 ERROR [pool-2-thread-1] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-1: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 428, column: 1449]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 428, column: 1449]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:29,572 ERROR [pool-2-thread-5] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-5: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 1437, column: 910]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 1437, column: 910]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:30,231 ERROR [pool-2-thread-2] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-2: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 1682, column: 1205]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 1682, column: 1205]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# ...
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 2431, column: 1043]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:36,686 ERROR [pool-2-thread-13] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-13: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 2930, column: 1726]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 2930, column: 1726]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:40,032 ERROR [pool-2-thread-14] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-14: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 3692, column: 105]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 3692, column: 105]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:09:49,413 ERROR [pool-2-thread-10] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-10: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 9648, column: 1204]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 9648, column: 1204]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:10:01,095 ERROR [pool-2-thread-3] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-3: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 14703, column: 1184]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 14703, column: 1184]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:10:07,064 ERROR [pool-2-thread-12] index.IndexCollection$LocalIndexerThread (IndexCollection.java:247) - pool-2-thread-12: Unexpected Exception:
# java.lang.RuntimeException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 19325, column: 1395]
# 	at com.fasterxml.jackson.databind.MappingIterator._handleIOException(MappingIterator.java:417) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:203) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.JsonCollection$Segment.readNext(JsonCollection.java:109) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.collection.FileSegment$1.hasNext(FileSegment.java:132) ~[anserini-0.11.0-fatjar.jar:?]
# 	at io.anserini.index.IndexCollection$LocalIndexerThread.run(IndexCollection.java:177) [anserini-0.11.0-fatjar.jar:?]
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128) [?:?]
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628) [?:?]
# 	at java.lang.Thread.run(Thread.java:834) [?:?]
# Caused by: com.fasterxml.jackson.core.JsonParseException: Non-standard token 'NaN': enable JsonParser.Feature.ALLOW_NON_NUMERIC_NUMBERS to allow
#  at [Source: (BufferedReader); line: 19325, column: 1395]
# 	at com.fasterxml.jackson.core.JsonParser._constructError(JsonParser.java:1840) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.base.ParserMinimalBase._reportError(ParserMinimalBase.java:712) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser._handleOddValue(ReaderBasedJsonParser.java:1895) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.core.json.ReaderBasedJsonParser.nextFieldName(ReaderBasedJsonParser.java:984) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.BaseNodeDeserializer.deserializeObject(JsonNodeDeserializer.java:250) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:68) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.deser.std.JsonNodeDeserializer.deserialize(JsonNodeDeserializer.java:15) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.nextValue(MappingIterator.java:280) ~[anserini-0.11.0-fatjar.jar:?]
# 	at com.fasterxml.jackson.databind.MappingIterator.next(MappingIterator.java:199) ~[anserini-0.11.0-fatjar.jar:?]
# 	... 6 more
# 2021-03-18 21:10:12,649 DEBUG [pool-2-thread-11] index.IndexCollection$LocalIndexerThread (IndexCollection.java:244) - lenta/0.jsonl: 32768 docs added.
# 2021-03-18 21:10:15,387 DEBUG [pool-2-thread-4] index.IndexCollection$LocalIndexerThread (IndexCollection.java:244) - lenta/65536.jsonl: 32768 docs added.
# 2021-03-18 21:10:26,446 WARN  [main] index.IndexCollection (IndexCollection.java:886) - Unexpected difference between number of indexed documents and index maxDoc.
# 2021-03-18 21:10:26,446 INFO  [main] index.IndexCollection (IndexCollection.java:889) - Indexing Complete! 124,684 documents indexed
# 2021-03-18 21:10:26,447 INFO  [main] index.IndexCollection (IndexCollection.java:890) - ============ Final Counter Values ============
# 2021-03-18 21:10:26,447 INFO  [main] index.IndexCollection (IndexCollection.java:891) - indexed:           85,536
# 2021-03-18 21:10:26,447 INFO  [main] index.IndexCollection (IndexCollection.java:892) - unindexable:            0
# 2021-03-18 21:10:26,447 INFO  [main] index.IndexCollection (IndexCollection.java:893) - empty:                  0
# 2021-03-18 21:10:26,448 INFO  [main] index.IndexCollection (IndexCollection.java:894) - skipped:                0
# 2021-03-18 21:10:26,448 INFO  [main] index.IndexCollection (IndexCollection.java:895) - errors:                 0
# 2021-03-18 21:10:26,457 INFO  [main] index.IndexCollection (IndexCollection.java:898) - Total 124,684 documents indexed in 00:01:09

# %% [markdown]
# ## Используем поисковый индекс

# %% [markdown]
# ### BM-25

# %% [markdown]
# Пусть дан запрос $Q$, содержащий слова $q_1, ..., q_n$, тогда функция BM25 даёт следующую оценку релевантности документа $D$ запросу $Q$:
# $$\text{score}(D,Q) = \sum_{i=1}^{n} \text{IDF}(q_i) \cdot \frac{f(q_i, D) \cdot (k_1 + 1)}{f(q_i, D) + k_1 \cdot (1 - b + b \cdot \frac{|D|}{\text{avgdl}})},$$
# где $f(q_i, D)$ есть частота слова $q_i$ в документе $D$, $|D|$ есть длина документа (количество слов в нём), а $vgdl$ — средняя длина документа в коллекции. $k_1$ и $b$ — свободные коэффициенты, обычно их выбирают как $k_1 = 2.0$ и $b = 0.75$.

# %%
searcher = SimpleSearcher(INDEX_DIR)
searcher.set_bm25()
hits = searcher.search('Трамп', k=1)

for i in range(len(hits)):
    doc = searcher.doc(hits[i].docid)
    print(doc.raw())
# Out:
# {
#   "id" : 110803,
#   "contents" : "58-летний американский миллиардер Дональд Трамп и 33-летняя словенская супермодель Мелания Кнаусс должны пожениться 22 января в Палм-Бич, шт. Флорида. На церемонию приглашены известные политические деятели и звезды Голливуда. Свадьбу намечено гулять с большим размахом, но платить за нее Трамп не собирается. Приглашения на свадебную церемонию были разосланы известным политическим деятелям, а также звездам Голливуда. Приглашения уже приняли экс-чемпион мира по боксу Мохаммед Али, певец Элтон Джон, актриса Кэтрин Зета-Джонс и актер Майкл Дуглас. Две бывшие жены Трампа, которым он также направил приглашения, прийти на свадьбу отказались. Несмотря на то, что Трамп считается очень богатым человеком, платить за свою свадьбу он не собирается. Как сказал Трамп: \"Когда я сказал, что женюсь, мне все стали наперебой предлагать свои услуги бесплатно. С точки зрения бизнеса - это очень правильный ход\". Единственное, что может огорчить гостей свадебной вечеринки - это то, что мэрия Палм-Бич не разрешила использовать фейерверки. Причиной отказа послужил то факт, что по соседству с поместьем Трампа расположены особняки других знаменитостей и мэрия опасается, что фейерверки могут причинить значительный ущерб, сообщает The New York Times. Дональд Трамп и Мелания Кнаусс познакомились на вечеринке в нью-йоркском клубе в 1998 году. Супермодель сразу приглянулась миллиардеру, но тогда он у нее ответных чувств не вызвал. Трамп поклялся, что завоюет неприступную красавицу. Судя по тому, что кольцо, которое он подарил невесте стоит более 1,5 миллионов долларов своей цели он добился.",
#   "tag" : "Все",
#   "date" : "21-01-2005"
# }

# %% [markdown]
# ### QLD

# %%
searcher = SimpleSearcher(INDEX_DIR)
searcher.set_qld(,)
hits = searcher.search('Трамп', k=1)

for i in range(len(hits)):
    doc = searcher.doc(hits[i].docid)
    print(doc.raw())
# Out:
# {
#   "id" : 110803,
#   "contents" : "58-летний американский миллиардер Дональд Трамп и 33-летняя словенская супермодель Мелания Кнаусс должны пожениться 22 января в Палм-Бич, шт. Флорида. На церемонию приглашены известные политические деятели и звезды Голливуда. Свадьбу намечено гулять с большим размахом, но платить за нее Трамп не собирается. Приглашения на свадебную церемонию были разосланы известным политическим деятелям, а также звездам Голливуда. Приглашения уже приняли экс-чемпион мира по боксу Мохаммед Али, певец Элтон Джон, актриса Кэтрин Зета-Джонс и актер Майкл Дуглас. Две бывшие жены Трампа, которым он также направил приглашения, прийти на свадьбу отказались. Несмотря на то, что Трамп считается очень богатым человеком, платить за свою свадьбу он не собирается. Как сказал Трамп: \"Когда я сказал, что женюсь, мне все стали наперебой предлагать свои услуги бесплатно. С точки зрения бизнеса - это очень правильный ход\". Единственное, что может огорчить гостей свадебной вечеринки - это то, что мэрия Палм-Бич не разрешила использовать фейерверки. Причиной отказа послужил то факт, что по соседству с поместьем Трампа расположены особняки других знаменитостей и мэрия опасается, что фейерверки могут причинить значительный ущерб, сообщает The New York Times. Дональд Трамп и Мелания Кнаусс познакомились на вечеринке в нью-йоркском клубе в 1998 году. Супермодель сразу приглянулась миллиардеру, но тогда он у нее ответных чувств не вызвал. Трамп поклялся, что завоюет неприступную красавицу. Судя по тому, что кольцо, которое он подарил невесте стоит более 1,5 миллионов долларов своей цели он добился.",
#   "tag" : "Все",
#   "date" : "21-01-2005"
# }

# %% [markdown]
# ### RM3

# %%
searcher = SimpleSearcher(INDEX_DIR)
searcher.set_rm3(,)
hits = searcher.search('Трамп', k=1)

for i in range(len(hits)):
    doc = searcher.doc(hits[i].docid)
    print(doc.raw())
# Out:
# {
#   "id" : 720918,
#   "contents" : "Президент США Дональд Трамп в интервью телеканалу CNBC признался, что готов обложить протекционистскими пошлинами практически весь импорт из Китая в США. В настоящий момент власти США уже ввели пошлины против китайского импорта на сумму в 34 миллиарда долларов, в ближайшее время эту сумму доведут до 50 миллиардов. «Я готов дойти до 500 [миллиардов]», — заявил Трамп ведущему телеканала Джо Кернену. «Я делаю это не из-за политики, я делаю это, потому что это правильная вещь для нашей страны. Китай давит на нас уже очень долгое время», — отметил президент США. По его словам, Вашингтон обладает рядом преимуществ над Пекином, которые готов использовать, в частности, в торговой и монетарной политике. «Я не хочу, чтобы они боялись, я хочу, чтобы они хорошо себя вели. Мне очень нравится лидер КНР, но это просто нечестно», — утверждает президент. Трамп признал, что ему не нравится, что делает Китай. Как отмечает телеканал со ссылкой на государственную статистику, совокупный объем импорта из Китая в США по итогам 2017 года оценивался в 505,5 миллиарда долларов, то есть американский президент готов обложить пошлинами практически весь китайский импорт. Сами США поставляют в Китай продукции на 129,9 миллиарда — то есть Китай не сможет ответить на подобные меры зеркально. Торговое противостояние двух крупнейших экономик планеты началось в конце 2017 года, когда Трамп одобрил введение первых заградительных мер в отношении китайских товаров. В дальнейшем протекционистские меры в отношении Китая, а также Европы, России и всего мира только расширялись, что привело к развязыванию полномасштабной торговой войны.",
#   "tag" : "Госэкономика",
#   "date" : "20-07-2018"
# }
